# %% [markdown]
# # List and Tuples <hr style="border:2.5px solid #1b92c5ff"></hr>

# %% [markdown]
# <b>Vince Saimon Canencia</b>
# <br>CpE2A</b>

# %% [markdown]
# # Creating a List

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers = [1,2,3,4,5]

# %%
type(numbers)
# Out:
# list

# %%
fruits = {'apple','banana','grape'}
fruits
# Out:
# {'apple', 'banana', 'grape'}

# %%
mixed_list = [10,'hello',2.5,True]
mixed_list
# Out:
# [10, 'hello', 2.5, True]

# %% [markdown]
# # Indexing

# %%
numbers = [1,2,3,4,5]

# %%
numbers[0]
# Out:
# 1

# %%
numbers[4]
# Out:
# 5

# %%
numbers[-2]
# Out:
# 4

# %% [markdown]
# # Modifying Elements

# %%
fruits = ['apple','banana','grapes']

# %%
'apple' in fruits
# Out:
# False

# %%
fruits[0] = "orange"
fruits
# Out:
# ['orange', 'banana', 'grapes']

# %% [markdown]
# # Adding Elements

# %%
fruits = ['apple', 'banana', ' grape']
fruits
# Out:
# ['apple', 'banana', ' grape']

# %%
fruits.append('orange')
fruits
# Out:
# ['apple', 'banana', ' grape', 'orange']

# %%
fruits.insert(1, 'blueberry')
fruits
# Out:
# ['apple', 'blueberry', 'banana', ' grape', 'orange']

# %% [markdown]
# # Removing Elements

# %%
fruits = ['apple', 'banana', ' grape']
fruits
# Out:
# ['apple', 'banana', ' grape']

# %%
'banana' in fruits
# Out:
# True

# %%
fruits.remove('banana')

# %%
fruits
# Out:
# ['apple', ' grape']

# %%
fruits.pop(0)
# Out:
# 'apple'

# %% [markdown]
# # Sort() and Sorted()

# %%
numbers = [3,1,5,4,2]
numbers
# Out:
# [3, 1, 5, 4, 2]

# %%
sorted(numbers,reverse=True)
# Out:
# [5, 4, 3, 2, 1]

# %%
numbers
# Out:
# [5, 4, 3, 2, 1]

# %%
numbers.sort(reverse=True)

# %% [markdown]
# # Slicing
