# %% [markdown]
# # Pandas Basics <hr style="border:2.5px solid #1b92c5ff"></hr>

# %% [markdown]
# <b>Vince Saimon Canencia</b>
# <br>CpE2A</b>

# %%
# %pip install matplotlib --upgrade

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # DataFrame

# %%
data = {
    "Name": ["Henry", "Owen", "Ada"],
    "Age": [22, 35, 58],
    "Sex": ["M", "M", "F"]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#     Name  Age Sex
# 0  Henry   22   M
# 1   Owen   35   M
# 2    Ada   58   F

# %% [markdown]
# # Series

# %%
df["Name"]
# Out:
# 0    Henry
# 1     Owen
# 2      Ada
# Name: Name, dtype: object

# %%
df["Age"]
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
df["Sex"]
# Out:
# 0    M
# 1    M
# 2    F
# Name: Sex, dtype: object

# %% [markdown]
# # Descriptive Statistics

# %%
resistance = np.array([
    [10.6, 9.1, 9.3, 9.8, 10.5, 10.4, 9.5, 11.0, 4.3, 9.8],
    [10.1, 11.9, 1.2, 9.2, 10.8, 8.9, 9.2, 9.1, 9.1, np.nan]
])

resistance
# Out:
# array([[10.6,  9.1,  9.3,  9.8, 10.5, 10.4,  9.5, 11. ,  4.3,  9.8],
#        [10.1, 11.9,  1.2,  9.2, 10.8,  8.9,  9.2,  9.1,  9.1,  nan]])

# %%
df = pd.DataFrame(resistance.T, columns=["Jaguar", "Panther"])
df
# Out:
#    Jaguar  Panther
# 0    10.6     10.1
# 1     9.1     11.9
# 2     9.3      1.2
# 3     9.8      9.2
# 4    10.5     10.8
# 5    10.4      8.9
# 6     9.5      9.2
# 7    11.0      9.1
# 8     4.3      9.1
# 9     9.8      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Jaguar   10 non-null     float64
#  1   Panther  9 non-null      float64
# dtypes: float64(2)
# memory usage: 292.0 bytes

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#          Jaguar    Panther
# count  10.00000   9.000000
# mean    9.43000   8.833333
# std     1.90441   3.032326
# min     4.30000   1.200000
# 25%     9.35000   9.100000
# 50%     9.80000   9.200000
# 75%    10.47500  10.100000
# max    11.00000  11.900000
